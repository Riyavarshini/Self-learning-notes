# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df2 = pd.read_csv("/kaggle/input/diabetes-dataset/diabetes.csv")
df3 = pd.read_csv('/kaggle/input/netflix-shows/netflix_titles.csv')

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/netflix-shows/netflix_titles.csv
# /kaggle/input/diabetes-dataset/diabetes.csv
# /kaggle/input/shoefly-orders/shoefly_orders .csv

# %% [markdown]
# ---
# # **<center><font color='indigo'>PYTHON PANDAS</font></center>**
#
# Pandas is a Python module for working with tabular data (i.e., data in a table with rows and columns). Tabular data has a lot of the same functionality as SQL or Excel, but Pandas adds the power of Python.
#
# In order to get access to the Pandas module, we’ll need to install the module and then import it into a Python file.
#
# ```python
# !pip install pandas
# ```
#
# ```python
# import pandas as pd
# ```

# %% [markdown]
# # **<font color='Maroon'>DATAFRAME</font>**
# The fundamental Pandas object is called a DataFrame. It is a 2-dimensional size-mutable, potentially heterogeneous, tabular data structure.
#
# A DataFrame can be created multiple ways. It can be created by passing in a dictionary or a list of lists to the `pd.DataFrame()` method, or by `reading data from a CSV file`.

# %% [markdown]
# ## **Ways of creating Pandas dataframe**

# %% [markdown]
# **1.Passing in a dictionary:**

# %%
student_data1 = {'name':['Arav','Brijesh','Cathrine','Manoj','Mansoor','Rani'],'id':[208,209,210,204,205,214],'rank':[4,2,1,3,6,5]}
student_df = pd.DataFrame(student_data1)
print(student_df)
# Out:
#        name   id  rank
# 0      Arav  208     4
# 1   Brijesh  209     2
# 2  Cathrine  210     1
# 3     Manoj  204     3
# 4   Mansoor  205     6
# 5      Rani  214     5

# %% [markdown]
# **2.Passing in a list of lists:**

# %%
sales_data = [['crayon',5,50,'20/07/2023'],['pencil',2,40,'22/06/2023'],['face cream',1,120,'14/11/2023']]
sales_df = pd.DataFrame(sales_data,columns =['product_name','quantity','totalprice','date'])
print(sales_df)
# Out:
#   product_name  quantity  totalprice        date
# 0       crayon         5          50  20/07/2023
# 1       pencil         2          40  22/06/2023
# 2   face cream         1         120  14/11/2023

# %% [markdown]
# **3.Reading data from a csv file:**
#
# * if you are working in your local pc provide the url where dataset is stored.
#
# **`df = pd.read_csv('/Users/../1_diagnosticCentres_1.csv')`**
#
# * if you are working in kaggle, just upload the dataset or choose the public dataset and copy the path and paste it inside the paranthesis between quotes.
#
# > make sure to run this code!
#
#
# ```python
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
# ```

# %% [markdown]
# **file type and corresponding function:**
#
# - csv -> read_csv('url/filename.csv)</br>
# - txt -> read_csv('url/filename.txt',sep = "separators used") </br>
# Comma (sep = ","), whitespace(sep = "\s"), tab (sep = "\t"), and colon(sep = ":")</br>
# - excel -> read_excel('url/filename.xlsx')</br>
# - excel_with_multiple_sheet -> read_excel('url/filename.xlsx',sheet_name = **'sheetname'** or **sheetposition**)</br>
# - json -> read_json()

# %% [markdown]
# **nested_json:**
#
# Nested JSON structure means that each key can have more keys associated with it.
#
# Reading a nested JSON can be done in multiple ways.
#
# First, you will use the `json.loads` function to read a JSON string by passing the data variable as a parameter to it.
#
# Then, you will use the `json_normalize` function to flatten the nested JSON data into a table.
#
#
#
#
# Next, you will flatten the JSON using the normalize function. You will pass in the complete data for now and see how it looks.
# `nested_full = json_normalize(nested)`

# %%
# sample nested json input
nested_json = """{
   "article": [

      {
         "id":"01",
         "language": "JSON",
         "edition": "first",
         "author": "Allen"
      },

      {
         "id":"02",
         "language": "Python",
         "edition": "second",
         "author": "Aditya Sharma"
      }
   ],

   "blog":[
   {
       "name": "Datacamp",
       "URL":"datacamp.com"
   }
   ]
}"""
print(nested_json)
'''In the above dataset,
you can observe that article and blog are two primary keys
under which there are values of these keys. '''
# Out:
# {
#    "article": [
#
#       {
#          "id":"01",
#          "language": "JSON",
#          "edition": "first",
#          "author": "Allen"
#       },
#
#       {
#          "id":"02",
#          "language": "Python",
#          "edition": "second",
#          "author": "Aditya Sharma"
#       }
#    ],
#
#    "blog":[
#    {
#        "name": "Datacamp",
#        "URL":"datacamp.com"
#    }
#    ]
# }
# 'In the above dataset,\nyou can observe that article and blog are two primary keys\nunder which there are values of these keys. '

# %%
#You will import the json_normalize function from the pandas.io.json library.
from pandas import json_normalize
import json  

nested = json.loads(nested_json)
nested_full = json_normalize(nested)

blog = json_normalize(nested,record_path ='blog')
article = json_normalize(nested,record_path ='article')

# %%
nested_full
# Out:
#                                              article  \
# 0  [{'id': '01', 'language': 'JSON', 'edition': '...
#
#                                             blog
# 0  [{'name': 'Datacamp', 'URL': 'datacamp.com'}]

# %% [markdown]
# ---
# # <font color='Maroon'>What can we do with Pandas?</font>
# In this example, we'll be working with data from ShoeFly.com, a fictional online shoe store.
# Just look and try to understand what we can do.
# will look into deeper later.

# %%
# load dataset in dataframe
df = pd.read_csv('/kaggle/input/shoefly-orders/shoefly_orders .csv')
df
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    Rebecca   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      Emily     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      Joyce    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     Justin  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     Andrew     Banks              AB4318@gmail.com         boots
# 5  52386      Julie     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     Thomas    Jensen              TJ5470@gmail.com         clogs
# 7  76971     Janice     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    Gabriel    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    Frances    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color
# 0  faux-leather      black
# 1  faux-leather       navy
# 2        fabric      black
# 3  faux-leather        red
# ...

# %%
df.head()
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    Rebecca   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      Emily     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      Joyce    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     Justin  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     Andrew     Banks              AB4318@gmail.com         boots
#
#   shoe_material shoe_color
# 0  faux-leather      black
# 1  faux-leather       navy
# 2        fabric      black
# 3  faux-leather        red
# 4       leather      brown

# %%
df.head(10)
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    Rebecca   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      Emily     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      Joyce    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     Justin  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     Andrew     Banks              AB4318@gmail.com         boots
# 5  52386      Julie     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     Thomas    Jensen              TJ5470@gmail.com         clogs
# 7  76971     Janice     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    Gabriel    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    Frances    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color
# 0  faux-leather      black
# 1  faux-leather       navy
# 2        fabric      black
# 3  faux-leather        red
# ...

# %% [markdown]
# #### .shape
# returns rowsxcolumns of the dataframe.

# %%
df.shape
# Out:
# (10, 7)

# %% [markdown]
# #### columns
# returns names of columns

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'shoe_type', 'shoe_material',
#        'shoe_color'],
#       dtype='object')

# %% [markdown]
# #### len()
# returns total number of rows in dataframe.

# %%
len(df)
# Out:
# 10

# %% [markdown]
# #### Printing values of column(s)

# %%
# individual column by dot method
df.first_name
# Out:
# 0    Rebecca
# 1      Emily
# 2      Joyce
# 3     Justin
# 4     Andrew
# 5      Julie
# 6     Thomas
# 7     Janice
# 8    Gabriel
# 9    Frances
# Name: first_name, dtype: object

# %%
# using bracket notation individual column
col1 = df['last_name']
col1
# Out:
# 0     Lindsay
# 1       Joyce
# 2      Waller
# 3    Erickson
# 4       Banks
# 5       Marsh
# 6      Jensen
# 7       Hicks
# 8      Porter
# 9      Palmer
# Name: last_name, dtype: object

# %%
# using bracket notation for multiple columns
columns = df[['first_name','last_name']]
columns
# Out:
#   first_name last_name
# 0    Rebecca   Lindsay
# 1      Emily     Joyce
# 2      Joyce    Waller
# 3     Justin  Erickson
# 4     Andrew     Banks
# 5      Julie     Marsh
# 6     Thomas    Jensen
# 7     Janice     Hicks
# 8    Gabriel    Porter
# 9    Frances    Palmer

# %% [markdown]
# #### Let's select everyone who ordered black sandals.

# %%
df[(df.shoe_type == 'sandals') & (df.shoe_color == 'black')]
# Out:
#       id first_name last_name                   email shoe_type shoe_material  \
# 2  91987      Joyce    Waller  Joyce.Waller@gmail.com   sandals        fabric
# 5  52386      Julie     Marsh  JulieMarsh59@gmail.com   sandals        fabric
#
#   shoe_color
# 2      black
# 5      black

# %% [markdown]
# #### Let's see what Janice Hicks ordered.

# %%
# dot method
df[(df.first_name == 'Janice') & (df.last_name == 'Hicks')]
# Out:
#       id first_name last_name                   email shoe_type shoe_material  \
# 7  76971     Janice     Hicks  Janice.Hicks@gmail.com     clogs  faux-leather
#
#   shoe_color
# 7       navy

# %%
# bracket notation
df[(df['first_name'] == 'Janice')&(df['last_name']=='Hicks')]
# Out:
#       id first_name last_name                   email shoe_type shoe_material  \
# 7  76971     Janice     Hicks  Janice.Hicks@gmail.com     clogs  faux-leather
#
#   shoe_color
# 7       navy

# %% [markdown]
# It looks like Janice ordered navy faux-leather clogs!
#
# ---

# %% [markdown]
# # <center><font color='Maroon'>VIEWING AND UNDERSTANDING DATAFRAMES</font></center>

# %%
df2 = pd.read_csv("/kaggle/input/diabetes-dataset/diabetes.csv")
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## .head()
# * returns first 5 rows.</br>
# * head(n) returns first n rows. n is natural number.

# %%
df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df2.head(12)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ## .tail()
# * return last 5 rows
# * tail(n) returns last n rows

# %%
df2.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df2.tail(12)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ## .describe()
# prints the summary statistics of all numeric columns, such as count, mean, standard deviation, range, and quartiles of numeric columns.</br>
# Can also modify quantile percentages.</br>
# Finally .T is used to transpose the result table for easier understanding.

# %%
df2.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df2.describe(percentiles =[0.3,0.5,0.8])
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 30%       1.000000  102.000000      64.000000       8.200000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 80%       7.000000  147.000000      82.000000      35.000000  150.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df2.describe().T
#rows and columns of previous result is transposed.
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# ## .info()
# a quick way to look at the data types, missing values, and data size of a DataFrame.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## .shape
# It is an attribute return a tuple (row, column) and can be indexed to get only rows, and only columns count as output.

# %%
df2.shape
# Out:
# (768, 9)

# %%
print('number of rows: {}'.format(df2.shape[0]))
print('number of columns: {}'.format(df2.shape[1]))
# Out:
# number of rows: 768
# number of columns: 9

# %% [markdown]
# ## .columns
# returns column names in form of index object.</br>
# It can be converted to a list using a list() function.

# %%
df2.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(list(df2.columns))
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %% [markdown]
# ## .dtypes
# Return the data types of each column.

# %%
df2.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ## .isnull()
# The `isnull()` method in pandas is used to detect missing or null values in a DataFrame.
#
# It returns a DataFrame of the same shape as the input, where each element is either `True` if the corresponding element in the original DataFrame is `NaN` (null), or False if the element is not null.

# %%
# importing new dataset
df3 = pd.read_csv('/kaggle/input/netflix-shows/netflix_titles.csv')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#total null in each columns
df3.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# total null in dataset
df3.isnull().sum().sum()
# Out:
# 4307

# %% [markdown]
# ## .notnull()
# It is used to detect non-null (non-missing) values in a DataFrame.
#
# The `notnull()` method returns a DataFrame of the same shape as the input, where each element is `True` if the corresponding element in the original DataFrame is `not null`, and False if the element is null (NaN).

# %%
print(df3.notnull().sum().sum())
print(df3.isnull().sum().sum())
# Out:
# 101377
# 4307

# %% [markdown]
# ## Isolating one column using [ ]
# This outputs `series` object. </br>
# **SERIES** is a one-dimensional array containing data of any type.

# %%
df3['type']
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %% [markdown]
# ## Isolating two or more columns using [[ ]]

# %%
df3[['type','title']]
# Out:
#          type                  title
# 0       Movie   Dick Johnson Is Dead
# 1     TV Show          Blood & Water
# 2     TV Show              Ganglands
# 3     TV Show  Jailbirds New Orleans
# 4     TV Show           Kota Factory
# ...       ...                    ...
# 8802    Movie                 Zodiac
# 8803  TV Show            Zombie Dumb
# 8804    Movie             Zombieland
# 8805    Movie                   Zoom
# 8806    Movie                 Zubaan
#
# [8807 rows x 2 columns]

# %% [markdown]
# ## Isolating one row using [ ]
# `.index` returns the row labels of the DataFrame, and the comparison turns that into a Boolean one-dimensional array.

# %%
df3[df3.index == 0]
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
df3[df3.index == 7]
# Out:
#   show_id   type    title      director  \
# 7      s8  Movie  Sankofa  Haile Gerima
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
#
#    release_year rating duration  \
# 7          1993  TV-MA  125 min
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...

# %% [markdown]
# ## Isolating two or more rows using [ ]
#
# * two or more rows can be returned using the .isin() method instead of a == operator.
# * we can also use >=, <= instead of == operator.

# %%
# list rows from 0 to 7
df3[df3.index <= 7]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
# list rows within the range 2 to 10 and skip by 2 rows in between
df3[df3.index.isin(range(2,10,2))]
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 4      s5  TV Show                      Kota Factory
# 6      s7    Movie  My Little Pony: A New Generation
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 4                            NaN
# 6  Robert Cullen, José Luis Ucha
# 8                Andy Devonshire
#
#                                                 cast         country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...             NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...           India
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...             NaN
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
#
#            date_added  release_year rating   duration  \
# 2  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Using .loc[] and .iloc[] to fetch rows
#
# * **loc[] (Label-based Indexing):** is primarily used for selection by row label(index name).
# * **iloc[] (integer-based Indexing):** is used for selection by position of row.(index position)

# %%
# Create a sample DataFrame
data = {'A': [1, 2, 3, 4, 5],
        'B': ['a', 'b', 'c', 'd', 'e']}
sample = pd.DataFrame(data, index=['one', 'two', 'three', 'four', 'five'])
sample
# Out:
#        A  B
# one    1  a
# two    2  b
# three  3  c
# four   4  d
# five   5  e

# %%
# specific row
sample.loc['three']
# Out:
# A    3
# B    c
# Name: three, dtype: object

# %%
# range of rows
sample.loc['two':'four']
# Out:
#        A  B
# two    2  b
# three  3  c
# four   4  d

# %%
# specific row
sample.iloc[3]
# Out:
# A    4
# B    d
# Name: four, dtype: object

# %%
# range of rows
sample.iloc[2:4]
# Out:
#        A  B
# three  3  c
# four   4  d

# %%
# fetching multiple rows of interest
sample.loc[['two','one','four']]
# Out:
#       A  B
# two   2  b
# one   1  a
# four  4  d

# %%
df3.iloc[[2,10,100]]
# Out:
#     show_id     type                                title         director  \
# 2        s3  TV Show                            Ganglands  Julien Leclercq
# 10      s11  TV Show  Vendetta: Truth, Lies and The Mafia              NaN
# 100    s101  TV Show              Tobot Galaxy Detectives              NaN
#
#                                                   cast country  \
# 2    Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 10                                                 NaN     NaN
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...     NaN
#
#              date_added  release_year rating   duration  \
# 2    September 24, 2021          2021  TV-MA   1 Season
# 10   September 24, 2021          2021  TV-MA   1 Season
# 100   September 7, 2021          2019  TV-Y7  2 Seasons
#
#                                              listed_in  \
# 2    Crime TV Shows, International TV Shows, TV Act...
# 10   Crime TV Shows, Docuseries, International TV S...
# ...

# %% [markdown]
# **Fetching specific rows and columns**

# %%
# fetching row with label two and column B
sample.loc['two','B'] # using loc[]
# Out:
# 'b'

# %%
sample.iloc[1,1] # using iloc[]
# Out:
# 'b'

# %% [markdown]
# **Update using loc and iloc**
# You can update/modify certain values by using the assignment operator `=`

# %%
data1 = {'Name': ['Alice', 'Bob', 'Charlie'],
         'Age': [25, 81, 30]}
data2 = {'Name': ['David', 'Eva', 'Frank'],
         'Age': [40, 81, 22]}
s1 = pd.DataFrame(data1,index = ['A','B','C'])
s2 = pd.DataFrame(data2,index = ['A','B','C'])
s1
# Out:
#       Name  Age
# A    Alice   25
# B      Bob   81
# C  Charlie   30

# %%
s1.loc['A' ,'Name'] = 'Nancy'
s1
# Out:
#       Name  Age
# A    Nancy   25
# B      Bob   81
# C  Charlie   30

# %%
s2
# Out:
#     Name  Age
# A  David   40
# B    Eva   81
# C  Frank   22

# %%
# lets change the age of eva from 81 to 36.
s2.iloc[1,1]= '36'
s2
# Out:
#     Name Age
# A  David  40
# B    Eva  36
# C  Frank  22

# %% [markdown]
# ---
# # <center><font color='Maroon'>FILTERING OR CONDITIONAL SLICING</font></center>

# %% [markdown]
# Lets use diabetes dataset[df2].</br>
# Now we wants
# 1. data where blood pressure <= 80.
# 2. outcome = 1
# 3. insulin = 0
# 4. need only columns insulin,bi,age for blood pressure <= 80

# %%
df2[df2.BloodPressure <= 80]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2[df2.Outcome == 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2[df2.Insulin == 0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2.loc[df2['BloodPressure']<=80,['BloodPressure','Insulin','BMI','Age']]
# Out:
#      BloodPressure  Insulin   BMI  Age
# 0               72        0  33.6   50
# 1               66        0  26.6   31
# 2               64        0  23.3   32
# 3               66       94  28.1   21
# 4               40      168  43.1   33
# ..             ...      ...   ...  ...
# 763             76      180  32.9   63
# 764             70        0  36.8   27
# 765             72      112  26.2   30
# 766             60        0  30.1   47
# 767             70        0  30.4   23
#
# [603 rows x 4 columns]

# %% [markdown]
# ## .query()
# The `.query()` method is used to filter a DataFrame based on a query expression. It provides a convenient way to select a subset of data that meets specific conditions without using traditional boolean indexing.

# %%
data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 30, 22],
        'Salary': [50000.0, 60000.0, 45000.0],
        'IsStudent': [False, False, True]}

d1 = pd.DataFrame(data)

# Use .query() to filter rows where Age is greater than 25
result = d1.query('Age > 25')

result
# Out:
#     Name  Age   Salary  IsStudent
# 1  Alice   30  60000.0      False

# %%
# age_threshold = int(input())
age_threshold = 40
result = d1.query('Age > @age_threshold')
result
# Out:
# Empty DataFrame
# Columns: [Name, Age, Salary, IsStudent]
# Index: []

# %% [markdown]
# To use multiple conditions in a .query() expression, you can combine them using logical operators such as **`&`** (AND), **`|`** (OR), and **`~`** (NOT).

# %%
df2.query('Glucose > 100 & Age < 50')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 761            9      170             74             31        0  44.0
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %% [markdown]
# ---
# # <center><font color='Maroon'>CLEANING DATA USING PANDAS</font></center>
#
# Let us use netflix dataset with null values. `[df3]`

# %%
# no. of null values in each columns
df3.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# These null values are generally deleted or replaced with other values.</br>
#
# ## DROPPING NULL VALUES - .dropna()
# This is particularly useful in cases where you have plenty of data and losing a small portion won’t impact the downstream analysis.

# %%
d1 = df3.copy()
d1 = d1.dropna()
print(df3.shape)
print(d1.shape)
# Out:
# (8807, 12)
# (5332, 12)

# %%
# we can check for non-null value using info()
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 541.5+ KB

# %% [markdown]
# The `axis` argument lets you specify whether you are dropping rows, or columns, with missing values.</br>The default axis removes the rows containing `NaNs`.</br>Use `axis = 1` to remove the columns with one or more NaN values.</br>Also, notice how we are using the argument `inplace=True` which lets you skip saving the output of `.dropna()` into a new DataFrame.

# %%
d1 = df3.copy()
d1.dropna(inplace = True, axis = 1)
d1
# Out:
#      show_id     type                  title  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead          2020
# 1         s2  TV Show          Blood & Water          2021
# 2         s3  TV Show              Ganglands          2021
# 3         s4  TV Show  Jailbirds New Orleans          2021
# 4         s5  TV Show           Kota Factory          2021
# ...      ...      ...                    ...           ...
# 8802   s8803    Movie                 Zodiac          2007
# 8803   s8804  TV Show            Zombie Dumb          2018
# 8804   s8805    Movie             Zombieland          2009
# 8805   s8806    Movie                   Zoom          2006
# 8806   s8807    Movie                 Zubaan          2015
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   release_year  8807 non-null   int64
#  4   listed_in     8807 non-null   object
#  5   description   8807 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 413.0+ KB

# %%
d1 = df3.copy()
d1.dropna(inplace = True, axis = 0)
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 541.5+ KB

# %% [markdown]
# **You can also drop both rows and columns with missing values by setting the how argument to `'all'`**

# %%
data = {'A': [1, np.nan, np.nan, 4,np.nan],
        'B': [np.nan, 2, 3, np.nan,np.nan],
        'C': [1, 2, 3, 4,np.nan],
        'D': [np.nan,np.nan,np.nan,np.nan,np.nan]}
d1 = pd.DataFrame(data)
d1
# Out:
#      A    B    C   D
# 0  1.0  NaN  1.0 NaN
# 1  NaN  2.0  2.0 NaN
# 2  NaN  3.0  3.0 NaN
# 3  4.0  NaN  4.0 NaN
# 4  NaN  NaN  NaN NaN

# %%
# axis = 1 removes column where all values are missing
d1.dropna(inplace= True,axis = 1, how = 'all')
d1
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  NaN  2.0  2.0
# 2  NaN  3.0  3.0
# 3  4.0  NaN  4.0
# 4  NaN  NaN  NaN

# %% [markdown]
# ## REPLACING MISSING VALUE WITH OTHER VALUES - .fillna()
# Instead of dropping, replacing missing values with a summary statistic or a specific value (depending on the use case) maybe the best way to go.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df3.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
x=df3[df3['cast'].isnull()]
x
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 3         s4  TV Show                              Jailbirds New Orleans
# 10       s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 14       s15  TV Show                    Crime Stories: India Detectives
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# ...      ...      ...                                                ...
# 8746   s8747    Movie                                             Winnie
# 8755   s8756  TV Show                                  Women Behind Bars
# 8756   s8757    Movie                                          Woodstock
# 8763   s8764    Movie                    WWII: Report from the Aleutians
# 8803   s8804  TV Show                                        Zombie Dumb
#
#                                            director cast  \
# ...

# %%
# lets replace nan value in cast to unknown
d1 = df3.copy()
d1['cast'].fillna('Unknown',inplace = True)
d1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Dealing with Duplicate Data - .drop_duplicates()

# %%
# netflix dataset has no duplicate data.
# So lets add a duplicate row to existing dataframe.
d1 = df3.copy() 
new_row = d1.loc[8806] # extract data of index = 8806
n = pd.DataFrame(new_row).T # create dataframe and transpose the result
d1 = pd.concat([d1,n],ignore_index = True) 
# The ignore_index=True parameter is used to reindex the resulting DataFrame. 
d1.tail()
# Out:
#      show_id     type        title         director  \
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
# 8807   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added release_year rating   duration  \
# 8803      July 1, 2019         2018  TV-Y7  2 Seasons
# 8804  November 1, 2019         2009      R     88 min
# 8805  January 11, 2020         2006     PG     88 min
# ...

# %%
# lets remove it
dropped_df = d1.drop_duplicates(subset = ['show_id'])
dropped_df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added release_year rating   duration  \
# 8802  November 20, 2019         2007      R    158 min
# 8803       July 1, 2019         2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# **Understanding subset parameter in .drop_duplicates()**

# %%
# what if show id is same but different type is there? so we need to search keys in pairs.
# lets add two new rows with same showid as s8807 and different type in one row.
d1 = df3.copy() 
new_row = d1.loc[[8806,8806]]
n = pd.DataFrame(new_row)
d1 = pd.concat([d1,n],ignore_index = True)
d1.loc[8808,'type'] = 'Drama'
d1.tail(5)
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
# 8807   s8807  Movie      Zubaan      Mozez Singh
# 8808   s8807  Drama      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8808  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
# ...

# %% [markdown]
# Now we have 3 rows with showid = s8807, in which two rows have duplicate values in all column.

# %%
# let's delete the duplicate pairs.
d1.drop_duplicates(subset = ['show_id','type'])
d1.tail()
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
# 8807   s8807  Movie      Zubaan      Mozez Singh
# 8808   s8807  Drama      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8808  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
# ...

# %% [markdown]
# From above result we could see there are two rows with same `showid = s8807` but different type.
#
# This is how subset works. We can add as many as column names.

# %% [markdown]
# ## COMBINING DATAFRAMES:
# ## pd.concat()
# Concatenate data frames along a particular axis.

# %%
d1 = df3.copy() 
new_row = d1.loc[[8806,8806]]
n = pd.DataFrame(new_row)
d1.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
d1 = pd.concat([d1,n],ignore_index = True)
d1.tail()
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
# 8807   s8807  Movie      Zubaan      Mozez Singh
# 8808   s8807  Movie      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8808  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
# ...

# %% [markdown]
# ## pd.merge()
# A function used to merge two DataFrames based on common columns or indices.
#
# It supports various types of joins, including inner, outer, left, and right joins.

# %%
x1 = pd.DataFrame({'key': ['A', 'B', 'C'], 'value': [1, 2, 3]})
x2 = pd.DataFrame({'key': ['B', 'C', 'D'], 'value': [4, 5, 6]})

result = pd.merge(x1, x2, on='key', how='outer')
result
# Out:
#   key  value_x  value_y
# 0   A      1.0      NaN
# 1   B      2.0      4.0
# 2   C      3.0      5.0
# 3   D      NaN      6.0

# %% [markdown]
# The `left_on` and `right_on` parameters in the `pd.merge()` function are used when you want to merge DataFrames based on columns with different names.

# %%
# Sample DataFrames
left_df = pd.DataFrame({'left_key': ['A', 'B', 'C'], 'value': [1, 2, 3]})
right_df = pd.DataFrame({'right_key': ['B', 'C', 'D'], 'value': [4, 5, 6]})

# Merge based on different column names using left_on and right_on
merged_df = pd.merge(left_df, right_df, left_on='left_key', right_on='right_key', how='inner')

merged_df
# Out:
#   left_key  value_x right_key  value_y
# 0        B        2         B        4
# 1        C        3         C        5

# %% [markdown]
# ## RENAMING COLUMNS
# ## .rename()
# With the .rename() method, you can use columns as an argument to rename specific columns.

# %%
d1 = df2.copy()
d1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# In this dataset we have a columns 'BloodPressure','DiabetesPedigreeFunction'.</br>Lets rename it to 'BP','DPF'.

# %%
d1.rename(columns={'BloodPressure':'BP','DiabetesPedigreeFunction':'DPF'},inplace = True)
d1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BP', 'SkinThickness', 'Insulin', 'BMI',
#        'DPF', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ## .columns
# You can also directly assign column names as a list to the DataFrame.

# %%
d1.columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DPF', 'Age', 'Outcome', 'STF']
d1.head()
# Here only the column name changes, column doesn't shifts accordingly.
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin  BMI   DPF    Age  Outcome  \
# 0        6            148             72       35    0  33.6  0.627       50
# 1        1             85             66       29    0  26.6  0.351       31
# 2        8            183             64        0    0  23.3  0.672       32
# 3        1             89             66       23   94  28.1  0.167       21
# 4        0            137             40       35  168  43.1  2.288       33
#
#    STF
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1

# %% [markdown]
# ***
#
# ## SORTING
# ## .sort_values(by = 'column')
# Sort the DataFrame by values in a specific column.

# %%
d1 = df2.sort_values(by = ['Glucose','BloodPressure'])
d1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 342            1        0             68             35        0  32.0
# 502            6        0             68             41        0  39.0
# 182            1        0             74             20       23  27.7
# 349            5        0             80             32        0  41.0
# ..           ...      ...            ...            ...      ...   ...
# 228            4      197             70             39      744  36.7
# 579            2      197             70             99        0  34.7
# 408            8      197             74              0        0  25.9
# 561            0      198             66             32      274  41.3
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# ...

# %% [markdown]
# ## .nlargest(n,'column')
# `nlargest()` is specifically used to get the first n rows with the largest values in one or more columns.

# %%
d1 = df2.nlargest(5,'Insulin')
d1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 13             1      189             60             23      846  30.1
# 228            4      197             70             39      744  36.7
# 247            0      165             90             33      680  52.3
# 584            8      124             76             24      600  28.7
# 409            1      172             68             49      579  42.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 13                      0.398   59        1
# 228                     2.329   31        0
# 247                     0.427   23        0
# 584                     0.687   52        1
# 409                     0.702   28        1

# %% [markdown]
# ---
#
# # <center><font color='Maroon'>ANALYSING USING PANDAS</font></center>
# ## .mean()
# **`Mean`** is a measure of central tendancy.
#
# **`Central tendency`** is a statistical measure that represents a central or typical value around which data points in a distribution tend to cluster. It provides a sense of the "center" of a set of values.

# %%
# let's use diabetes dataset (df2)
# For each columns
df2.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
# For specific columns
df2[['Age','BMI']].mean()
# Out:
# Age    33.240885
# BMI    31.992578
# dtype: float64

# %%
# For particular column
df2.Age.mean() # or df2['Age'].mean()
# Out:
# 33.240885416666664

# %% [markdown]
# ## .median()
# It is used to calculate the median of a DataFrame or Series.
#
# Note that non-numeric columns are automatically excluded when calculating the median for the entire DataFrame.

# %%
df2.median() # all columns
df2.Age.median() # for only Age column
df2[['Age','BMI']].median() # for multiple columns
# Out:
# Age    29.0
# BMI    32.0
# dtype: float64

# %% [markdown]
# ## .mode()
#
# It is used to calculate the mode of a DataFrame or Series. The mode is the value that appears most frequently in a dataset.

# %%
df2.mode() # all columns
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
print('number of time glucose value 99 appear: {}'.format(len(df2.loc[df2['Glucose']==99])))
print('number of time glucose value 100 appear: {}'.format(len(df2.loc[df2['Glucose']==100])))
# Out:
# number of time glucose value 99 appear: 17
# number of time glucose value 100 appear: 17

# %% [markdown]
# ## Create calculated fields
# calculated fields refer to creating new columns in a DataFrame based on calculations involving existing columns.

# %% [markdown]
# Let's create a column to categories Age group as Adult,Senior Adult,Super Senior.

# %%
d1 = df2.copy()
conditions = [
    (d1['Age'] >= 21) & (d1['Age'] < 40),
    (d1['Age'] >= 40) & (d1['Age'] < 60),
    (d1['Age'] >= 60)
]
choices = ['Adults', 'Senior Adults', 'Super Senior']
d1['Age_Group'] = np.select(conditions, choices, default='Unknown')
d1.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome      Age_Group
# 763                     0.171   63        0   Super Senior
# 764                     0.340   27        0         Adults
# 765                     0.245   30        0         Adults
# 766                     0.349   47        1  Senior Adults
# 767                     0.315   23        0         Adults

# %% [markdown]
# ## .value_counts()
# It is used to get a Series containing counts of unique values.
#
# It's often applied to a column in a DataFrame to understand the distribution of values within that column.

# %%
# single column with categorical data
d1['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults           561
# Senior Adults    175
# Super Senior      32
# Name: count, dtype: int64

# %%
# unique combinations of columns
d1.value_counts(subset = ['Age_Group','Outcome'])
# Out:
# Age_Group      Outcome
# Adults         0          401
#                1          160
# Senior Adults  1           99
#                0           76
# Super Senior   0           23
#                1            9
# Name: count, dtype: int64

# %%
d1['Age_Group'].value_counts(normalize = True)
# Out:
# Age_Group
# Adults           0.730469
# Senior Adults    0.227865
# Super Senior     0.041667
# Name: proportion, dtype: float64

# %% [markdown]
# ## Aggregating data with .groupby()
# `.groupby()` function is used for grouping data based on some criteria and then applying a function or summary method to each group independently.
#
# Any summary method can be used alongside `.groupby()`, including `.min()`, `.max()`, `.mean()`, `.median()`, `.sum()`, `.mode()`, and more.

# %%
# Aggregating data by one column
d1.groupby('Age_Group').median()
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Age_Group
# Adults                 2.0    112.0           70.0           23.0     52.0
# Senior Adults          7.0    126.0           78.0           24.0      0.0
# Super Senior           5.0    135.5           78.0            0.0      0.0
#
#                 BMI  DiabetesPedigreeFunction   Age  Outcome
# Age_Group
# Adults         31.6                    0.3750  26.0      0.0
# Senior Adults  33.6                    0.3490  45.0      1.0
# Super Senior   28.4                    0.4395  64.5      0.0

# %%
# Aggregating data by multiple column
d1.groupby(['Age_Group','Outcome']).mean()
# Out:
#                        Pregnancies     Glucose  BloodPressure  SkinThickness  \
# Age_Group     Outcome
# Adults        0           2.561097  108.022444      66.628429      20.723192
#               1           3.481250  140.012500      66.593750      23.056250
# Senior Adults 0           6.513158  113.828947      74.684211      16.368421
#               1           7.202020  141.949495      76.747475      21.191919
# Super Senior  0           5.521739  131.391304      73.826087      12.086957
#               1           3.777778  155.777778      80.888889      17.000000
#
#                           Insulin        BMI  DiabetesPedigreeFunction  \
# Age_Group     Outcome
# Adults        0         75.887781  30.090524                  0.428860
#               1         98.925000  35.763750                  0.586081
# Senior Adults 0         42.223684  32.381579                  0.437421
#               1        106.737374  34.446465                  0.496727
# ...

# %% [markdown]
# Additionally, you can use the `.agg()` method to apply multiple aggregation functions at once.

# %%
# Applying multiple method for all columns.
d1.groupby('Age_Group').agg(['sum','mean'])
# Out:
#               Pregnancies           Glucose             BloodPressure  \
#                       sum      mean     sum        mean           sum
# Age_Group
# Adults               1584  2.823529   65719  117.146168         37373
# Senior Adults        1208  6.902857   22704  129.737143         13274
# Super Senior          161  5.031250    4424  138.250000          2426
#
#                          SkinThickness            Insulin                 BMI  \
#                     mean           sum       mean     sum       mean      sum
# Age_Group
# Adults         66.618538         11999  21.388592   46259  82.458111  17788.5
# Senior Adults  75.851429          3342  19.097143   13776  78.720000   5871.2
# Super Senior   75.812500           431  13.468750    1251  39.093750    910.6
#
#                          DiabetesPedigreeFunction              Age             \
#                     mean                      sum      mean    sum       mean
# Age_Group
# ...

# %%
# Applying multiple method for selected columns
d1.groupby('Age_Group').agg({'Glucose':['mean','median'],'BloodPressure':['mean','median']})
# Out:
#                   Glucose        BloodPressure
#                      mean median          mean median
# Age_Group
# Adults         117.146168  112.0     66.618538   70.0
# Senior Adults  129.737143  126.0     75.851429   78.0
# Super Senior   138.250000  135.5     75.812500   78.0

# %% [markdown]
# ## pd.pivot_table
#
# `pd.pivot_table()` is a function in pandas that provides a way to create a spreadsheet-style pivot table as a DataFrame. It allows you to specify which columns to use as the index, which columns to use as the columns, and which column to use for populating the values in the table.

# %%
pd.pivot_table(d1, values="BMI", index=['Glucose','Age_Group'],columns=['Outcome'], aggfunc=np.mean,sort = False)
# Out:
# Outcome                   1       0
# Glucose Age_Group
# 148     Senior Adults  35.6     NaN
#         Adults         30.9  32.500
# 85      Senior Adults   NaN  27.800
#         Adults         29.0  31.025
# 183     Senior Adults   NaN  40.800
# ...                     ...     ...
# 56      Adults          NaN  24.200
# 169     Adults         29.9     NaN
# 149     Senior Adults  29.3     NaN
# 65      Senior Adults   NaN  32.000
# 190     Super Senior   35.5     NaN
#
# [249 rows x 2 columns]

# %%
pd.pivot_table(d1,values = 'SkinThickness' ,index = ['BloodPressure'],columns = ['Age_Group'],aggfunc = np.mean)
# Out:
# Age_Group         Adults  Senior Adults  Super Senior
# BloodPressure
# 0               0.793103       6.000000          0.00
# 24             19.000000            NaN           NaN
# 30             40.000000            NaN           NaN
# 38             18.000000            NaN           NaN
# 40             35.000000            NaN           NaN
# 44             25.000000            NaN           NaN
# 46             20.000000            NaN           NaN
# 48             23.000000            NaN           NaN
# 50             23.833333            NaN          0.00
# 52             18.100000       0.000000           NaN
# 54             18.000000            NaN          0.00
# 55              0.000000      20.000000           NaN
# 56             20.750000            NaN           NaN
# 58             22.700000      33.000000           NaN
# 60             21.032258      15.500000         16.50
# 61                   NaN       0.000000           NaN
# ...

# %% [markdown]
# ## pd.to_datetime()
# it is used to convert an argument to a datetime. This function can parse a wide variety of formats and return a datetime object, which is useful for working with time-related data in pandas DataFrames.

# %%
data = {'date_column': ['2022-01-01', '2022-02-15', '2022-03-23']}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_column  3 non-null      object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
# Converting the 'date_column' to datetime
df['date_column'] = pd.to_datetime(df['date_column'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_column  3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %% [markdown]
# Let's see another example !

# %%
data = {
    'year': [2022, 2023, 2022],
    'month': [1, 5, 11],
    'day': [15, 20, 25],
    'hour': [8, 15, 12],
    'minute': [30, 45, 0]
}

df = pd.DataFrame(data)
df
# Out:
#    year  month  day  hour  minute
# 0  2022      1   15     8      30
# 1  2023      5   20    15      45
# 2  2022     11   25    12       0

# %%
df['combined_datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute']])
df
# Out:
#    year  month  day  hour  minute   combined_datetime
# 0  2022      1   15     8      30 2022-01-15 08:30:00
# 1  2023      5   20    15      45 2023-05-20 15:45:00
# 2  2022     11   25    12       0 2022-11-25 12:00:00

# %% [markdown]
# ## pd.date_range()
# generate a fixed-frequency DatetimeIndex, which is essentially an array of datetime values.
#
# **`pd.date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize=False, name=None, closed=None, **kwargs)`**

# %%
date_index = pd.date_range(start='2022-01-01', end='2022-07-10', freq='W')
date_index
# Out:
# DatetimeIndex(['2022-01-02', '2022-01-09', '2022-01-16', '2022-01-23',
#                '2022-01-30', '2022-02-06', '2022-02-13', '2022-02-20',
#                '2022-02-27', '2022-03-06', '2022-03-13', '2022-03-20',
#                '2022-03-27', '2022-04-03', '2022-04-10', '2022-04-17',
#                '2022-04-24', '2022-05-01', '2022-05-08', '2022-05-15',
#                '2022-05-22', '2022-05-29', '2022-06-05', '2022-06-12',
#                '2022-06-19', '2022-06-26', '2022-07-03', '2022-07-10'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %% [markdown]
# ## df.resample()
#  is used for resampling time-series data.

# %%
date_rng = pd.date_range(start='2022-01-01', end='2022-01-10', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df
# Out:
#         date
# 0 2022-01-01
# 1 2022-01-02
# 2 2022-01-03
# 3 2022-01-04
# 4 2022-01-05
# 5 2022-01-06
# 6 2022-01-07
# 7 2022-01-08
# 8 2022-01-09
# 9 2022-01-10

# %%
df['data'] = np.random.randn(len(df))
df
# Out:
#         date      data
# 0 2022-01-01 -0.355330
# 1 2022-01-02 -0.750892
# 2 2022-01-03 -1.087199
# 3 2022-01-04 -0.377064
# 4 2022-01-05  2.126483
# 5 2022-01-06 -0.132162
# 6 2022-01-07  1.060363
# 7 2022-01-08  1.693548
# 8 2022-01-09  0.579820
# 9 2022-01-10  2.101336

# %%
df.set_index('date', inplace=True)
df
# Out:
#                 data
# date
# 2022-01-01 -0.355330
# 2022-01-02 -0.750892
# 2022-01-03 -1.087199
# 2022-01-04 -0.377064
# 2022-01-05  2.126483
# 2022-01-06 -0.132162
# 2022-01-07  1.060363
# 2022-01-08  1.693548
# 2022-01-09  0.579820
# 2022-01-10  2.101336

# %%
'''We use resample('W') to resample the data to a weekly frequency.
The argument 'W' stands for weekly.'''

weekly_resampled = df.resample('W').mean()
weekly_resampled
# Out:
#                 data
# date
# 2022-01-02 -0.553111
# 2022-01-09  0.551970
# 2022-01-16  2.101336

# %% [markdown]
# ---

# %% [markdown]
# # <center><font color='Maroon'>VISUALIZING USING PANDAS</font></center>
# Pandas provides a built-in plotting interface
# ## Line plots
# pandas enables you to chart out the relationships among variables using line plots.

# %%
df2[['BMI', 'Glucose']].plot.line()
# Out:
# <Axes: >

# %%
df2[['BMI', 'Glucose']].plot.line(figsize=(20, 10), 
                                 color={"BMI": "purple", "Glucose": "crimson"})
# Out:
# <Axes: >

# %% [markdown]
# ### Attributes of plot.line()
#
# - **linestyle**: Style of the line. It can be '-', '--', '-.', ':', or 'None'.
#
# - **marker:** Style of the marker on data points. Common options include 'o', 's', '^', 'D', etc.
#
# - **color:** Line color.
#
# - **linewidth:** Width of the line.
#
# - **markersize:** Size of the markers.
#
# - **markerfacecolor:** Color of the marker face.
#
# - **markeredgecolor:** Color of the marker edge.
#
# - **alpha:** Transparency of the line and markers (0 for fully transparent, 1 for fully opaque).
#
# - **label:** Label for the legend.

# %%
df2[['Glucose','BMI','BloodPressure']].plot.line(figsize = (20,15),subplots=True,color={"Glucose": "crimson","BMI": "purple","BloodPressure":"Gold"},alpha = 0.7,linestyle='--',marker ='o',markersize=8,linewidth=1.5,markerfacecolor='pink',markeredgecolor='black')
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ## Barplot

# %%
df2['Outcome'].value_counts().plot.bar(color='mediumvioletred')
# Out:
# <Axes: xlabel='Outcome'>

# %% [markdown]
# ## Boxplot

# %%
df2.boxplot(by='Outcome',figsize = (10,10),layout =(4,2))
# Out:
# array([[<Axes: title={'center': 'Age'}, xlabel='[Outcome]'>,
#         <Axes: title={'center': 'BMI'}, xlabel='[Outcome]'>],
#        [<Axes: title={'center': 'BloodPressure'}, xlabel='[Outcome]'>,
#         <Axes: title={'center': 'DiabetesPedigreeFunction'}, xlabel='[Outcome]'>],
#        [<Axes: title={'center': 'Glucose'}, xlabel='[Outcome]'>,
#         <Axes: title={'center': 'Insulin'}, xlabel='[Outcome]'>],
#        [<Axes: title={'center': 'Pregnancies'}, xlabel='[Outcome]'>,
#         <Axes: title={'center': 'SkinThickness'}, xlabel='[Outcome]'>]],
#       dtype=object)

# %% [markdown]
# ___

# %% [markdown]
# ## <font color='red'>OTHER USEFUL FUNCTIONS AND ATTRIBUTES</font>
# ## pd.cut()
#  It is used for binning or grouping continuous data into discrete intervals or bins.

# %%
# Generate sample data with ages between 21 and 80
np.random.seed(42)
ages = np.random.randint(21, 81, size=100)

# Define bin edges
bins = [20, 30, 40, 50, 60, 70, 80]

len(ages)
# Out:
# 100

# %%
# Use pd.cut() to create age groups
age_groups = pd.cut(ages, bins=bins, right=True, labels=['21-30', '31-40', '41-50', '51-60', '61-70', '71-80'])

# Create a DataFrame for visualization
df = pd.DataFrame({'Age': ages, 'Age Group': age_groups})

# Display the DataFrame
print(df.head(10))
# Out:
#    Age Age Group
# 0   59     51-60
# 1   72     71-80
# 2   49     41-50
# 3   35     31-40
# 4   63     61-70
# 5   28     21-30
# 6   41     41-50
# 7   59     51-60
# 8   78     71-80
# 9   39     31-40

# %% [markdown]
# ## Series.map(func)
# The map() method in pandas is used to transform values in a Series based on a mapping or a provided function.

# %%
# Sample Series
s = pd.Series([1, 2, 3, 4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# Define a function for mapping
def square(x):
    return x ** 2

# Use map to transform values based on the function
squared_s = s.map(square)

print(squared_s)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# dtype: int64

# %% [markdown]
# ## DataFrame.applymap(func)
#  This method is used to apply a function to each element of a DataFrame.

# %%
# Sample DataFrame
data = {'A': [1.234, 2.567, 3.789],
        'B': [4.321, 5.432, 6.543]}
df = pd.DataFrame(data)
df
# Out:
#        A      B
# 0  1.234  4.321
# 1  2.567  5.432
# 2  3.789  6.543

# %%
# Define a custom rounding function
def custom_round(value):
    return round(value, 2)

# Apply the custom rounding function to each element of the DataFrame
rounded_df = df.applymap(custom_round)

rounded_df
# Out:
#       A     B
# 0  1.23  4.32
# 1  2.57  5.43
# 2  3.79  6.54

# %% [markdown]
# ---
# ## <font color='red'>NOTES TO REMEMBER</font>
# **1. Difference between `df.columnname` and `df['columnname']`:**
# * `df.columnname` is designed to retrieve a single column from a Pandas DataFrame.
# * `df['columnname']` is used to retrieve single column as well as multiple columns as `df[['column1','column2']]`
#
# **2. Understanding output of `mode()`:**
# *  the mode() function returns a DataFrame with all modal values.
# * If a column had a single mode, the corresponding entry in the result would be that mode.
# * If there were no modes, the entry would be `NaN`.
# * If there are multiple modes they are also included in the result.
#
# **3. `.value_counts(sort,normalize)`:**
# * The default sorting is based on the counts in descending order `sort = True`
# * `sort = False` will sort by ascending order
# * Adding the `normalize = True` argument returns relative frequencies instead of absolute counts.
#
# **4. `pd.pivot_table()` parameters:**
# * Here's a breakdown of the commonly used parameters:
#     * **data** (DataFrame: The data to be used for creating the pivot table.)
#     * **values=None** (Column name or list of column names to aggregate. These will be the values in the pivot table.)
#     * **index=None** (Column name or list of column names to be used as the index (rows) in the pivot table.)
#     * **columns=None** (Column name or list of column names to be used as the columns in the pivot table.)
#     * **aggfunc='mean'** (Aggregation function or a dictionary of column names and aggregation functions.)
#     * **fill_value=None** (A scalar value to replace missing values in the pivot table.)
#     * **margins=False** (If True, adds an 'All' row and column to the pivot table with the overall mean/sum of the data.)
#     * **margins_name='All'** (The name to use for the 'All' row and column if margins is set to True.)
#
#  **5. Difference between `df.sort_values()` and `df.nlargest()`:**
#  * `sort_values()` is used to sort a DataFrame or Series based on the values in one or more columns.
#      * DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, ...)
#  * `nlargest()` is specifically used to get the first n rows with the largest values in one or more columns.
#      * DataFrame.nlargest(n, columns, keep='first')
#
#  **6. Some colors to use in visualization:**
#
# ![Screenshot 2023-11-30 at 2.18.09 PM.png](attachment:d299b692-98d2-4d6f-a5b3-73496bdb7420.png)

# %% [markdown]
# ___
#
# **<center>TO KNOW MORE ABOUT PANDAS FUNCTIONS! FOLLOW UP MY PAGE!</center>**
